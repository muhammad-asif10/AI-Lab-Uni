# %%
#Task 1
a = int(input("Enter first number:"))
b = int(input("Enter second number:"))
if a>b:
    print("Greatr number:", a)
elif b>a:
    print("Greatr number:", b)
else:
    print("Both are equal:", a)
# Out:
# Enter first number: 23
# Enter second number: 45
# Greatr number: 45

# %%
#Task2
marks = int(input("Enter marks (0-100):"))
if marks < 0 or marks > 100:
    print("invaild marks. please enter between 0 and 100.")
elif marks >= 80:
    print(" Grade A - Excellent")
elif marks >= 60:
    print(" Grade B - Good.")
elif marks >= 50:
    print(" Grade C - Pass.")
else:
    print(" Fail  - Needs improvement")
# Out:
# Enter marks (0-100): 90
#  Grade A - Excellent

# %%
#task 3
n = int(input("Enter a number:"))
if n%2 == 0:
    print(n, "is Even")
else:
    print(n,"is Odd")
# Out:
# Enter a number: 12
# 12 is Even

# %%
#task4
CORRECT_USER = "admin"
CORRECT_PASS = "1234"
attempts = 3

while attempts > 0:
    u = input("Username: ")
    p = input("Password: ")

    if u == CORRECT_USER and p == CORRECT_PASS:
        print("Login Successful ✅")
        break   # yahan loop turant band ho jayega
    else:
        attempts -= 1
        print("Invalid credentials. Attempts left:", attempts)

    if attempts == 0:
        print("Account locked (demo). Please try later.")
# Out:
# Username:  admin
# Password:  1234
# Login Successful ✅

# %%
#task5
num = int(input("Enter a number for table:"))
for i in range(1, 11):
    print(f"{num} x {i} = {num * i} ")
# Out:
# Enter a number for table: 12
# 12 x 1 = 12
# 12 x 2 = 24
# 12 x 3 = 36
# 12 x 4 = 48
# 12 x 5 = 60
# 12 x 6 = 72
# 12 x 7 = 84
# 12 x 8 = 96
# 12 x 9 = 108
# 12 x 10 = 120

# %%
#task 6
import random
secret = random.randint(1, 20) # secret number in [1, 20]
print("I'm thinking of a number between 1 and 20...")
while True:
    guess = int(input("your guess:"))
    if guess == secret:
        print("Correct! You guessed it.")
        break
    elif guess < secret:
        print("Too low, try again.")
    else:
        print("Too high, try again.")
# Out:
# I'm thinking of a number between 1 and 20...
# your guess: 17
# Too high, try again.
# your guess: 3
# Too low, try again.
# your guess: 6
# Too high, try again.
# your guess: 8
# Too high, try again.
# your guess: 77
# Too high, try again.
